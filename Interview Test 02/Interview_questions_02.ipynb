# %% [markdown]
# # 1. Given the following function

# %% [markdown]
# # 𝑓 (𝑥,𝑡) = (𝑒^(−𝜔 𝑡^2)) cos(𝑛𝜋𝑥/l)

# %%
from sympy import *
x, t, 𝜔, 𝑛, l , 𝑒, 𝜋 = symbols('x t 𝜔 𝑛 l 𝑒 𝜋')
init_printing(use_unicode=True)

# %% [markdown]
# 𝑎)𝜕𝑓/𝜕𝑥

# %%
diff((𝑒** - ( 𝜔 * 𝑡**2))* cos(𝑛*𝜋*𝑥/l),x)
# Out:
#     2
#   -t ⋅𝜔        ⎛x⋅𝑛⋅𝜋⎞
# -𝑒     ⋅𝑛⋅𝜋⋅sin⎜─────⎟
#                ⎝  l  ⎠
# ───────────────────────
#            l

# %% [markdown]
# 𝑏)𝜕𝑓/𝜕t

# %%
diff((𝑒** - ( 𝜔 * 𝑡**2))* cos(𝑛*𝜋*𝑥/l),t)
# Out:
#         2
#       -t ⋅𝜔             ⎛x⋅𝑛⋅𝜋⎞
# -2⋅t⋅𝑒     ⋅𝜔⋅log(𝑒)⋅cos⎜─────⎟
#                         ⎝  l  ⎠

# %% [markdown]
# ## 2. Give an example of a linear vector space (with a basis)

# %% [markdown]
# X,y= 2 , 3
# 3x , -4y = 5 , -12

# %% [markdown]
# # 3.Find the inverse for the matrix 𝐴 =
# # ( a  b
# #   c  d )

# %% [markdown]
# A^-1 = ( d  -b
#        -c   a)

# %% [markdown]
# # 4. Give a definition and an example of a supervised learning algorithm

# %% [markdown]
# Aprendizado supervisionado é quando fornecemos ao computador uma grande fonte de dados formatadas em " Chave : Valor". Espera-se que o computador extraia padrōes dos dados fornecidos e assim possa predizer resultados fulturos. Quanto maior for o Dataset maior é a precisāo da maquina

# %% [markdown]
# Ex : Modelo de Regressao Linear para prever vendas de carros no seguinte ano

# %% [markdown]
# # 5. Give a definition and an example of a unsupervised learning algorithm

# %% [markdown]
# Aprendizado nāo supervisionado consiste em fornecer uma quantia de variaveis que por algum motivo nāo possāo
# estar relacionadas, cabe ao programa identificar os padrōes e condensar as informacoes para avaliarmos a relevancia
# delas

# %% [markdown]
# ex: Recomendaçōes de filmes por perfil de usuario na Netflix

# %% [markdown]
# # 6. Name 3 types of metrics, and their formulas, used in K-Means clustering algorithm

# %% [markdown]
# 1 - Correlacao de Pearson

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2- Overlap

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3- Camberra

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 7. Name and describe any algorithm to inverte a Matrix

# %%
import numpy as np

matrix = np.matrix([[30, 10], [19, 97]])

matrix_inv = np.linalg.inv(matrix)

print(matrix_inv)
# Out:
# [[ 0.03566176 -0.00367647]
#  [-0.00698529  0.01102941]]

# %% [markdown]
# funçāo do numpy de inversao de matrizes

# %% [markdown]
# # 8. Explain what is a logistic regression and give an example of application (describe it as best as you can).

# %% [markdown]
# Regressāo Logistica é a tecnica utilizada para obter prediçoes de uma fonte de dados categoricos. Consiste em alimentar um computador com dados de formataçāo binaria para que possam se obter padrōes e assim prever possivel resultados futuros. Ou para categorizar novos dados. É o fundamento por traz das redes neurais

# %% [markdown]
# Ex: Classificar o grau de gravidade de uma doenca de paciente de acordo com os sintomas

# %% [markdown]
# # 9.Describe in steps how would you perform preliminary analysis on a dataset

# %% [markdown]
# 1- Verificar Fonte, para ter certeza que estamos trabalhando com um Dataset confiavel
# 2- Verificar formatos dos arquivos
# 3- Upar em notebook
# 4- Avaliar formatações e Corrigir informaçōes
# 5- Ajustar colunas nescessarias
# 6- Eliminar colunas nāo nescessarias
# 7- Criar colunas que possam ser uteis
# 8- Tratar dados Nulos

# %% [markdown]
# # 10. Given the two tables A and B, give the result for the query below

# %%
import pandas as pd 
A = {
    'ID' : ['9991','9992','9993','9994'],
    'Name': ['John','Paul','Ringo','George'],
    'Born_in' : ['Liverpool','Liverpool','Liverpool','Liverpool']
}
B = {
    'ID' : ['9991','9992','9993','9995','9992'],
    'Instrument': ['Vocal','Base','Drums','Guitar','Piano'],
    'Futball_club' : ['Liverpool','Liverpool','Liverpool','Arsenal','Liverpool']
}

dfa = pd.DataFrame(A).set_index('ID')
dfb = pd.DataFrame(B).set_index('ID')
display(dfa)
display(dfb)
# Out:
#         Name    Born_in
# ID
# 9991    John  Liverpool
# 9992    Paul  Liverpool
# 9993   Ringo  Liverpool
# 9994  George  Liverpool
#      Instrument Futball_club
# ID
# 9991      Vocal    Liverpool
# 9992       Base    Liverpool
# 9993      Drums    Liverpool
# 9995     Guitar      Arsenal
# 9992      Piano    Liverpool

# %%
dfa.join(dfb,how= 'left')
# Out:
#         Name    Born_in Instrument Futball_club
# ID
# 9991    John  Liverpool      Vocal    Liverpool
# 9992    Paul  Liverpool       Base    Liverpool
# 9992    Paul  Liverpool      Piano    Liverpool
# 9993   Ringo  Liverpool      Drums    Liverpool
# 9994  George  Liverpool        NaN          NaN
